# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('50_Startups.csv')
np.set_printoptions(precision=2)
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
# It is telling that there is no null value

for i in range(0,5):
    print(dataset[dataset.isnull().iloc[:,i]])
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,4].values

# %%
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'Florida'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'Florida'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'Florida'],
#        [100671.96, 91790.61, 249744.55, 'California'],
#        [93863.75, 127320.38, 249839.44, 'Florida'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
y
# Out:
# array([ 192261.83,  191792.06,  191050.39,  182901.99,  166187.94,
#         156991.12,  156122.51,  155752.6 ,  152211.77,  149759.96,
#         146121.95,  144259.4 ,  141585.52,  134307.35,  132602.65,
#         129917.04,  126992.93,  125370.37,  124266.9 ,  122776.86,
#         118474.03,  111313.02,  110352.25,  108733.99,  108552.04,
#         107404.34,  105733.54,  105008.31,  103282.38,  101004.64,
#          99937.59,   97483.56,   97427.84,   96778.92,   96712.8 ,
#          96479.51,   90708.19,   89949.14,   81229.06,   81005.76,
#          78239.91,   77798.83,   71498.49,   69758.98,   65200.33,
#          64926.08,   49490.75,   42559.73,   35673.41,   14681.4 ])

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
label_encoder = LabelEncoder()

X[:,3] = label_encoder.fit_transform(X[:,3])
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 2],
#        [162597.7, 151377.59, 443898.53, 0],
#        [153441.51, 101145.55, 407934.54, 1],
#        [144372.41, 118671.85, 383199.62, 2],
#        [142107.34, 91391.77, 366168.42, 1],
#        [131876.9, 99814.71, 362861.36, 2],
#        [134615.46, 147198.87, 127716.82, 0],
#        [130298.13, 145530.06, 323876.68, 1],
#        [120542.52, 148718.95, 311613.29, 2],
#        [123334.88, 108679.17, 304981.62, 0],
#        [101913.08, 110594.11, 229160.95, 1],
#        [100671.96, 91790.61, 249744.55, 0],
#        [93863.75, 127320.38, 249839.44, 1],
#        [91992.39, 135495.07, 252664.93, 0],
#        [119943.24, 156547.42, 256512.92, 1],
#        [114523.61, 122616.84, 261776.23, 2],
#        [78013.11, 121597.55, 264346.06, 0],
#        [94657.16, 145077.58, 282574.31, 2],
#        [91749.16, 114175.79, 294919.57, 1],
#        [86419.7, 153514.11, 0.0, 2],
#        [76253.86, 113867.3, 298664.47, 0],
# ...

# %%
onehotencoder = OneHotEncoder(categorical_features=[3])
X = onehotencoder.fit_transform(X).toarray()

# %%
X
# Out:
# array([[  0.00e+00,   0.00e+00,   1.00e+00,   1.65e+05,   1.37e+05,
#           4.72e+05],
#        [  1.00e+00,   0.00e+00,   0.00e+00,   1.63e+05,   1.51e+05,
#           4.44e+05],
#        [  0.00e+00,   1.00e+00,   0.00e+00,   1.53e+05,   1.01e+05,
#           4.08e+05],
#        [  0.00e+00,   0.00e+00,   1.00e+00,   1.44e+05,   1.19e+05,
#           3.83e+05],
#        [  0.00e+00,   1.00e+00,   0.00e+00,   1.42e+05,   9.14e+04,
#           3.66e+05],
#        [  0.00e+00,   0.00e+00,   1.00e+00,   1.32e+05,   9.98e+04,
#           3.63e+05],
#        [  1.00e+00,   0.00e+00,   0.00e+00,   1.35e+05,   1.47e+05,
#           1.28e+05],
#        [  0.00e+00,   1.00e+00,   0.00e+00,   1.30e+05,   1.46e+05,
#           3.24e+05],
#        [  0.00e+00,   0.00e+00,   1.00e+00,   1.21e+05,   1.49e+05,
#           3.12e+05],
#        [  1.00e+00,   0.00e+00,   0.00e+00,   1.23e+05,   1.09e+05,
#           3.05e+05],
#        [  0.00e+00,   1.00e+00,   0.00e+00,   1.02e+05,   1.11e+05,
# ...

# %%
# Avoiding dummy variable trap
# But library takes care of it automatically(you don't have to do this explicitly) 
X = X[:,1:]

# %%
X
# Out:
# array([[  0.00e+00,   1.00e+00,   1.65e+05,   1.37e+05,   4.72e+05],
#        [  0.00e+00,   0.00e+00,   1.63e+05,   1.51e+05,   4.44e+05],
#        [  1.00e+00,   0.00e+00,   1.53e+05,   1.01e+05,   4.08e+05],
#        [  0.00e+00,   1.00e+00,   1.44e+05,   1.19e+05,   3.83e+05],
#        [  1.00e+00,   0.00e+00,   1.42e+05,   9.14e+04,   3.66e+05],
#        [  0.00e+00,   1.00e+00,   1.32e+05,   9.98e+04,   3.63e+05],
#        [  0.00e+00,   0.00e+00,   1.35e+05,   1.47e+05,   1.28e+05],
# array([  89949.14,  156991.12,  152211.77,  105733.54,  155752.6 ,
#         110352.25,   97483.56,   77798.83,   96778.92,  149759.96,
#          71498.49,  146121.95,   78239.91,  129917.04,  108552.04,
#         141585.52,   42559.73,   49490.75,   97427.84,   14681.4 ,
#          69758.98,   81229.06,   96712.8 ,  191792.06,  107404.34,
#         144259.4 ,   96479.51,   35673.41,  108733.99,   99937.59,
#         191050.39,  105008.31,  125370.37,  126992.93,  111313.02,
#         192261.83,  166187.94])

# %%
y_test
# Out:
# array([ 122776.86,   90708.19,  103282.38,  132602.65,  118474.03,
#          64926.08,   81005.76,  156122.51,  134307.35,   65200.33,
#         124266.9 ,  101004.64,  182901.99])

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

regressor.fit(X_train,y_train)
y_pred  = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([ 111915.9 ,   74176.05,  100154.64,  150207.08,  116935.2 ,
#          42448.57,   83400.4 ,  158728.62,  127623.31,   62110.6 ,
#         129917.54,   97857.93,  173037.87])

# %%
# Let's consider significance level of a model as 5%(0.05)

import statsmodels.formula.api as sm
X = np.append(arr = np.ones((50,1)).astype(int),values=X ,axis=1)

# %%
X
# Out:
# array([[  1.00e+00,   0.00e+00,   1.00e+00,   1.65e+05,   1.37e+05,
#           4.72e+05],
#        [  1.00e+00,   0.00e+00,   0.00e+00,   1.63e+05,   1.51e+05,
#           4.44e+05],
#        [  1.00e+00,   1.00e+00,   0.00e+00,   1.53e+05,   1.01e+05,
#           4.08e+05],
#        [  1.00e+00,   0.00e+00,   1.00e+00,   1.44e+05,   1.19e+05,
#           3.83e+05],
#        [  1.00e+00,   1.00e+00,   0.00e+00,   1.42e+05,   9.14e+04,
#           3.66e+05],
#        [  1.00e+00,   0.00e+00,   1.00e+00,   1.32e+05,   9.98e+04,
#           3.63e+05],
#        [  1.00e+00,   0.00e+00,   0.00e+00,   1.35e+05,   1.47e+05,
#           1.28e+05],
#        [  1.00e+00,   1.00e+00,   0.00e+00,   1.30e+05,   1.46e+05,
#           3.24e+05],
#        [  1.00e+00,   0.00e+00,   1.00e+00,   1.21e+05,   1.49e+05,
#           3.12e+05],
#        [  1.00e+00,   0.00e+00,   0.00e+00,   1.23e+05,   1.09e+05,
#           3.05e+05],
#        [  1.00e+00,   1.00e+00,   0.00e+00,   1.02e+05,   1.11e+05,
# ...

# %%
X_opt = X[:,[0,1,2,3,4,5]]
regressor_OLS = sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Thu, 04 May 2017   Prob (F-statistic):           1.34e-27
# Time:                        02:37:35   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       5.013e+04   6884.820      7.281      0.000      3.62e+04   6.4e+04
# ...

# %%
X_opt = X[:,[0,1,3,4,5]]
regressor_OLS = sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Thu, 04 May 2017   Prob (F-statistic):           8.49e-29
# Time:                        02:38:28   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       5.011e+04   6647.870      7.537      0.000      3.67e+04  6.35e+04
# ...

# %%
X_opt = X[:,[0,3,4,5]]
regressor_OLS = sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Thu, 04 May 2017   Prob (F-statistic):           4.53e-30
# Time:                        02:38:59   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       5.012e+04   6572.353      7.626      0.000      3.69e+04  6.34e+04
# ...

# %%
X_opt = X[:,[0,3,5]]
regressor_OLS = sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Thu, 04 May 2017   Prob (F-statistic):           2.16e-31
# Time:                        02:39:30   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       4.698e+04   2689.933     17.464      0.000      4.16e+04  5.24e+04
# ...

# %%
X_opt = X[:,[0,3]]
regressor_OLS = sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Thu, 04 May 2017   Prob (F-statistic):           3.50e-32
# Time:                        02:41:11   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       4.903e+04   2537.897     19.320      0.000      4.39e+04  5.41e+04
# ...

# %%
# END
